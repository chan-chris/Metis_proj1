# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import date
from datetime import time

# %%
#initialise the number of weeks for the dataset
num_weeks = 2

#initialise the date for the first week of the dataset (week ending on start_date)
start_date = filedate = pd.Timestamp('2019-06-01 00:00:00')

#initialise the regex for the MTA turnstile url
filename_regex = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"

filelist = []

for numfiles in range (num_weeks):

    # create the appropriate filename for the week
    filedate_str = str(filedate.year)[2:4] + str(filedate.month).zfill(2) + str(filedate.day).zfill(2)
    filename = filename_regex.format(filedate_str)

    # read the file and append it to the list of files to be concacated
    #df = pd.read_csv(filename, parse_dates=['DATE'], keep_date_col=True)
    df = pd.read_csv(filename, keep_date_col=True)
    filelist.append(df)

    # advance to the next week
    filedate += pd.Timedelta(days=7)

mta_df = pd.concat(filelist, axis=0, ignore_index=True)

# %%
mta_df.head()
#mta_df.dtypes
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7071830
# 1  REGULAR  7071844
# 2  REGULAR  7071864
# 3  REGULAR  7071943
# 4  REGULAR  7072182
#
#    EXITS
# 0                                            2396411
# 1                                            2396415
# 2                                            2396443
# 3                                            2396500
# 4                                            2396555

# %%
mta_df["DATE_TIME"] = pd.to_datetime(mta_df.DATE + mta_df.TIME, format='%m/%d/%Y%H:%M:%S')

# %%
mta_df.dtypes
# Out:
# C/A                                                                             object
# UNIT                                                                            object
# SCP                                                                             object
# STATION                                                                         object
# LINENAME                                                                        object
# DIVISION                                                                        object
# DATE                                                                            object
# TIME                                                                            object
# DESC                                                                            object
# ENTRIES                                                                          int64
# EXITS                                                                            int64
# ...

# %%
mta_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7071830
# 1  REGULAR  7071844
# 2  REGULAR  7071864
# 3  REGULAR  7071943
# 4  REGULAR  7072182
#
#    EXITS                                                                 \
# 0                                            2396411
# 1                                            2396415
# 2                                            2396443
# 3                                            2396500
# 4                                            2396555
#
#             DATE_TIME
# 0 2019-05-25 00:00:00
# ...

# %%
stations = pd.read_csv('http://web.mta.info/developers/data/nyct/subway/Stations.csv')

# %%
stations.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#               Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  Astoria-Ditmars Blvd       Q            N W  Elevated      40.775036
# 1          Astoria Blvd       Q            N W  Elevated      40.770258
# 2                 30 Av       Q            N W  Elevated      40.766779
# 3              Broadway       Q            N W  Elevated      40.761820
# 4                 36 Av       Q            N W  Elevated      40.756804
#
#    GTFS Longitude   North Direction Label South Direction Label  ADA ADA Notes
# 0      -73.912034                     NaN             Manhattan    0       NaN
# ...

# %%
stations.columns
# Out:
# Index(['Station ID', 'Complex ID', 'GTFS Stop ID', 'Division', 'Line',
#        'Stop Name', 'Borough', 'Daytime Routes', 'Structure', 'GTFS Latitude',
#        'GTFS Longitude', 'North Direction Label', 'South Direction Label',
#        'ADA', 'ADA Notes'],
#       dtype='object')

# %%
stations_samp=stations[0:10]
stations_samp.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#               Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  Astoria-Ditmars Blvd       Q            N W  Elevated      40.775036
# 1          Astoria Blvd       Q            N W  Elevated      40.770258
# 2                 30 Av       Q            N W  Elevated      40.766779
# 3              Broadway       Q            N W  Elevated      40.761820
# 4                 36 Av       Q            N W  Elevated      40.756804
#
#    GTFS Longitude   North Direction Label South Direction Label  ADA ADA Notes
# 0      -73.912034                     NaN             Manhattan    0       NaN
# ...

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", stations_samp.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  Station ID                 0
# Complex ID                 0
# GTFS Stop ID               0
# Division                   0
# Line                       0
# Stop Name                  0
# Borough                    0
# Daytime Routes             0
# Structure                  0
# GTFS Latitude              0
# GTFS Longitude             0
# North Direction Label      4
# South Direction Label      7
# ADA                        0
# ADA Notes                195
# dtype: int64

# %%
# geopy
from geopy.geocoders import Nominatim

# %%
import geopy
import pandas as pd

def get_zipcode(df, geolocator, lat_field, lon_field):
    location = geolocator.reverse((df[lat_field], df[lon_field]),timeout=None)
    print(location.raw['address']['postcode'])    
    #print(location.raw)    
    return location.raw['address']['postcode'] 

geolocator = geopy.Nominatim(user_agent='geoapiExercises')

# %%
zipcodes = stations_samp.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='GTFS Latitude', lon_field='GTFS Longitude')
# Out:
# 11101
# 11102
# 11101
# 11101
# 11106
# 11101
# 10022
# 10153
# 10019
# 10019

# %%
print(type(zipcodes))
# Out:
# <class 'pandas.core.series.Series'>
# ERROR! Session/line number was not unique in database. History logging moved to new session 47

# %%
### uszip method

from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=False)
# Out:
# Start downloading data for rich info zipcode database, total size 450+MB ...
#   10 MB finished ...
#   20 MB finished ...
#   30 MB finished ...
#   40 MB finished ...
#   50 MB finished ...
#   60 MB finished ...
#   70 MB finished ...
#   80 MB finished ...
#   90 MB finished ...
#   100 MB finished ...
#   110 MB finished ...
#   120 MB finished ...
#   130 MB finished ...
#   140 MB finished ...
#   150 MB finished ...
#   160 MB finished ...
#   170 MB finished ...
#   180 MB finished ...
#   190 MB finished ...
#   200 MB finished ...
#   210 MB finished ...
#   220 MB finished ...
#   230 MB finished ...
#   240 MB finished ...
#   250 MB finished ...
#   260 MB finished ...
#   270 MB finished ...
#   280 MB finished ...
#   290 MB finished ...
#   300 MB finished ...
#   310 MB finished ...
#   320 MB finished ...
#   330 MB finished ...
#   340 MB finished ...
#   350 MB finished ...
#   360 MB finished ...
#   370 MB finished ...
#   380 MB finished ...
# ...

# %%
from multiprocessing import cpu_count

# %%
cpu_count()
# Out:
# 8

# %%
# _lat=39.12321
# _lon=-77.12312
# _lat=stations_samp['GTFS Latitude']
# _lon=stations_samp['GTFS Longitude']

def getincome(_lat,_lon):
    # take a row
#     _lat=r['GTFS Latitude']
#     _lon=r['GTFS Longitude']
    
    #result = search.by_coordinates(_lat,_lon, radius=2,returns=None)    
    result='test'
#print(result) # by default 5 results returned

stations_samp.apply(getincome  , axis=1, _lat='GTFS Latitude', _lon='GTFS Longitude')
stations_samp.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='GTFS Latitude', lon_field='GTFS Longitude')

# for zipcode in result:
#     print(zipcode.median_household_income,zipcode.zipcode)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-222-1ff386bedb7f>", line 15, in <module>
#     stations_samp.apply(getincome, axis=1, _lat='GTFS Latitude', _lon='GTFS Longitude')
#   File "/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 7548, in apply
#     return op.get_result()
#   File "/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py", line 180, in get_result
#     return self.apply_standard()
# ...

# %%
# get list of coordinates (lat,lon) and apply to function
slen=len(stations_samp)
result=[]

# for i in range(slen):
    #x=stations_samp['GTFS Latitude']
    #y=stations_samp['GTFS Longitude']
#     result=search.by_coordinates(x,y)    
# print(x,y)

# x=mta_df['GTFS Latitude'] =39.12229
# y=mta_df['GTFS Longitude']=-77.1333

x=[39.12229,39.1443]
y=[-77.1333,-77.1454]

for i in x:
    result = search.by_coordinates(lat=x,lng=y, radius=5)

for zipcode in result:
    print(zipcode.median_household_income,zipcode.zipcode)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-210-018bcd5e228f> in <module>
#      16
#      17 for i in x:
# ---> 18     result = search.by_coordinates(lat=x,lng=y, radius=5)
#      19
#      20 for zipcode in result:
#
# /opt/anaconda3/lib/python3.8/site-packages/uszipcode/search.py in by_coordinates(self, lat, lng, radius, zipcode_type, sort_by, ascending, returns)
#     692           限定的半径的直接丢弃.
#     693         """
# --> 694         return self.query(
#     695             lat=lat, lng=lng, radius=radius,
#     696             sort_by=sort_by, zipcode_type=zipcode_type,
#
# ...

# %%
mta_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7071830
# 1  REGULAR  7071844
# 2  REGULAR  7071864
# 3  REGULAR  7071943
# 4  REGULAR  7072182
#
#    EXITS                                                                 \
# 0                                            2396411
# 1                                            2396415
# 2                                            2396443
# 3                                            2396500
# 4                                            2396555
#
#             DATE_TIME
# 0 2019-05-25 00:00:00
# ...

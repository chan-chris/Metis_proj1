# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import date
from datetime import time

# %%
#initialise the number of weeks for the dataset
num_weeks = 2

#initialise the date for the first week of the dataset (week ending on start_date)
start_date = filedate = pd.Timestamp('2019-06-01 00:00:00')

#initialise the regex for the MTA turnstile url
filename_regex = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"

filelist = []

for numfiles in range (num_weeks):

    # create the appropriate filename for the week
    filedate_str = str(filedate.year)[2:4] + str(filedate.month).zfill(2) + str(filedate.day).zfill(2)
    filename = filename_regex.format(filedate_str)

    # read the file and append it to the list of files to be concacated
    #df = pd.read_csv(filename, parse_dates=['DATE'], keep_date_col=True)
    df = pd.read_csv(filename, keep_date_col=True)
    filelist.append(df)

    # advance to the next week
    filedate += pd.Timedelta(days=7)

mta_df = pd.concat(filelist, axis=0, ignore_index=True)

# %%
mta_df.head()
#mta_df.dtypes
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7071830
# 1  REGULAR  7071844
# 2  REGULAR  7071864
# 3  REGULAR  7071943
# 4  REGULAR  7072182
#
#    EXITS
# 0                                            2396411
# 1                                            2396415
# 2                                            2396443
# 3                                            2396500
# 4                                            2396555

# %%
mta_df["DATE_TIME"] = pd.to_datetime(mta_df.DATE + mta_df.TIME, format='%m/%d/%Y%H:%M:%S')

# %%
mta_df.dtypes

# %%
mta_df.head()

# %%
stations = pd.read_csv('http://web.mta.info/developers/data/nyct/subway/Stations.csv')

# %%
stations.head()

# %%
stations.columns

# %%
stations_samp=stations[0:10]
stations_samp.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#               Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  Astoria-Ditmars Blvd       Q            N W  Elevated      40.775036
# 1          Astoria Blvd       Q            N W  Elevated      40.770258
# 2                 30 Av       Q            N W  Elevated      40.766779
# 3              Broadway       Q            N W  Elevated      40.761820
# 4                 36 Av       Q            N W  Elevated      40.756804
#
#    GTFS Longitude   North Direction Label South Direction Label  ADA ADA Notes
# 0      -73.912034                     NaN             Manhattan    0       NaN
# 1      -73.917843            Ditmars Blvd             Manhattan    1       NaN
# 2      -73.921479  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 3      -73.925508  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 4      -73.929575  Astoria - Ditmars Blvd             Manhattan    0       NaN

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", stations_samp.isnull().sum())

# %%
# geopy
from geopy.geocoders import Nominatim

# %%
import geopy
import pandas as pd

def get_zipcode(df, geolocator, lat_field, lon_field):
    location = geolocator.reverse((df[lat_field], df[lon_field]),timeout=None)
    print(location.raw['address']['postcode'])    
    #print(location.raw)    
    return location.raw['address']['postcode'] 

geolocator = geopy.Nominatim(user_agent='geoapiExercises')

# %%
zipcodes = stations_samp.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='GTFS Latitude', lon_field='GTFS Longitude')

# %%
print(type(zipcodes))

# %%
### uszip method

from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=False)

# %%
from multiprocessing import cpu_count

# %%
cpu_count()

# %%
stations_samp.columns
# Out:
# Index(['Station ID', 'Complex ID', 'GTFS Stop ID', 'Division', 'Line',
#        'Stop Name', 'Borough', 'Daytime Routes', 'Structure', 'GTFS Latitude',
#        'GTFS Longitude', 'North Direction Label', 'South Direction Label',
#        'ADA', 'ADA Notes'],
#       dtype='object')

# %%
def get_zipcode(df, geolocator, lat_field, lon_field):
    location = geolocator.reverse((df[lat_field], df[lon_field]),timeout=None)
    print(location.raw['address']['postcode'])    
    #print(location.raw)    
    return location.raw['address']['postcode'] 

geolocator = geopy.Nominatim(user_agent='geoapiExercises')

zipcodes = stations_samp.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='GTFS Latitude', lon_field='GTFS Longitude')

# %%
def getincome(_lat,_lng):
    income = search.by_coordinates((df[_lat],df[_lng]),radius=2,returns=None)    
    result='test'

stations_samp['income'] = stations_samp.apply(getincome,_lat='GTFS Latitude',_lng='GTFS Longitude')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-0c5235cde9fb> in <module>
#       3     result='test'
#       4
# ----> 5 stations_samp['income'] = stations_samp.apply(getincome,_lat='GTFS Latitude',_lng='GTFS Longitude')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in f(x)
#     107
#     108             def f(x):
# --> 109                 return func(x, *args, **kwds)
#     110
#     111         else:
#
# TypeError: getincome() got multiple values for argument '_lat'

# %%
## WORKING!!!

def getincome(_lat,_lon):
    income = search.by_coordinates(_lat,_lon, radius=2,returns=1)[0].median_household_income
    result='test'
    return income

stations_samp['income'] = stations_samp.apply(lambda row:  getincome(row['GTFS Latitude'], row['GTFS Longitude']) ,axis=1)
# Out:
# <ipython-input-63-e6a442357114>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_samp['income'] = stations_samp.apply(lambda row:  getincome(row['GTFS Latitude'], row['GTFS Longitude']) ,axis=1)

# %%
stations_samp.head(20)
# Out:
#    Station ID  Complex ID GTFS Stop ID Division                 Line  \
# 0           1           1          R01      BMT              Astoria
# 1           2           2          R03      BMT              Astoria
# 2           3           3          R04      BMT              Astoria
# 3           4           4          R05      BMT              Astoria
# 4           5           5          R06      BMT              Astoria
# 5           6           6          R08      BMT              Astoria
# 6           7         613          R11      BMT              Astoria
# 7           8           8          R13      BMT              Astoria
# 8           9           9          R14      BMT  Broadway - Brighton
# 9          10          10          R15      BMT  Broadway - Brighton
#
#               Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  Astoria-Ditmars Blvd       Q            N W  Elevated      40.775036
# 1          Astoria Blvd       Q            N W  Elevated      40.770258
# 2                 30 Av       Q            N W  Elevated      40.766779
# 3              Broadway       Q            N W  Elevated      40.761820
# 4                 36 Av       Q            N W  Elevated      40.756804
# 5     39 Av-Dutch Kills       Q            N W  Elevated      40.752882
# 6    Lexington Av/59 St       M          N W R    Subway      40.762660
# 7            5 Av/59 St       M          N W R    Subway      40.764811
# 8            57 St-7 Av       M        N Q R W    Subway      40.764664
# 9                 49 St       M          N R W    Subway      40.759901
#
#    GTFS Longitude   North Direction Label South Direction Label  ADA  \
# 0      -73.912034                     NaN             Manhattan    0
# 1      -73.917843            Ditmars Blvd             Manhattan    1
# 2      -73.921479  Astoria - Ditmars Blvd             Manhattan    0
# 3      -73.925508  Astoria - Ditmars Blvd             Manhattan    0
# 4      -73.929575  Astoria - Ditmars Blvd             Manhattan    0
# 5      -73.932755  Astoria - Ditmars Blvd             Manhattan    0
# 6      -73.967258                  Queens   Downtown & Brooklyn    0
# 7      -73.973347                  Queens   Downtown & Brooklyn    0
# 8      -73.980658         Uptown & Queens   Downtown & Brooklyn    0
# 9      -73.984139         Uptown & Queens   Downtown & Brooklyn    2
#
#      ADA Notes    income
# 0          NaN   57525.0
# 1          NaN   49924.0
# 2          NaN   49924.0
# 3          NaN   49924.0
# 4          NaN   48720.0
# 5          NaN   48720.0
# 6          NaN  115519.0
# 7          NaN       NaN
# 8          NaN       NaN
# 9  Uptown only       NaN

# %%
#df['race_label'] = df.apply (lambda row: label_race(row), axis=1)

def getincome(_lat,_lon):
# take a row
#     _lat=r['GTFS Latitude']
#     _lon=r['GTFS Longitude']

    # result = search.by_coordinates(_lat,_lon, radius=2,returns=None)    
    result='test'

#stations_samp.apply(getincome  , axis=1, _lon='GTFS Longitude')
stations_samp['income'] = stations_samp.apply( lambda row:  getincome(row['GTFS Latitude'], row['GTFS Longitude']) )
# stations_samp['zips'] = stations_samp.apply(lambda row: row['GTFS Latitude'] ,row['GTFS Longitude'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-1af17dac54b3> in <module>
#      10
#      11 #stations_samp.apply(getincome  , axis=1, _lon='GTFS Longitude')
# ---> 12 stations_samp['income'] = stations_samp.apply( lambda row:  getincome(row['GTFS Latitude'], row['GTFS Longitude']) )
#      13 # stations_samp['zips'] = stations_samp.apply(lambda row: row['GTFS Latitude'] ,row['GTFS Longitude'], axis=1)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-42-1af17dac54b3> in <lambda>(row)
#      10
#      11 #stations_samp.apply(getincome  , axis=1, _lon='GTFS Longitude')
# ---> 12 stations_samp['income'] = stations_samp.apply( lambda row:  getincome(row['GTFS Latitude'], row['GTFS Longitude']) )
#      13 # stations_samp['zips'] = stations_samp.apply(lambda row: row['GTFS Latitude'] ,row['GTFS Longitude'], axis=1)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: 'GTFS Latitude'

# %%
# _lat=39.12321
# _lon=-77.12312
# _lat=stations_samp['GTFS Latitude']
# _lon=stations_samp['GTFS Longitude']

def getincome(_lon):
# take a row
#     _lat=r['GTFS Latitude']
#     _lon=r['GTFS Longitude']
    
    # result = search.by_coordinates(_lat,_lon, radius=2,returns=None)    
    result='test'
    
#print(result) # by default 5 results returned

# stations_samp.apply(getincome  , axis=1, _lat='GTFS Latitude', _lon='GTFS Longitude')
stations_samp.apply(getincome  , axis=1, _lon='GTFS Longitude')

#stations_samp.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='GTFS Latitude', lon_field='GTFS Longitude')

# for zipcode in result:
#     print(zipcode.median_household_income,zipcode.zipcode)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-da15c8ffaa17> in <module>
#      15
#      16 # stations_samp.apply(getincome  , axis=1, _lat='GTFS Latitude', _lon='GTFS Longitude')
# ---> 17 stations_samp.apply(getincome  , axis=1, _lon='GTFS Longitude')
#      18
#      19 #stations_samp.apply(get_zipcode, axis=1, geolocator=geolocator, lat_field='GTFS Latitude', lon_field='GTFS Longitude')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in f(x)
#     107
#     108             def f(x):
# --> 109                 return func(x, *args, **kwds)
#     110
#     111         else:
#
# TypeError: getincome() got multiple values for argument '_lon'

# %%
# get list of coordinates (lat,lon) and apply to function
# slen=len(stations_samp)
# result=[]

# for i in range(slen):
    #x=stations_samp['GTFS Latitude']
    #y=stations_samp['GTFS Longitude']
#     result=search.by_coordinates(x,y)    
# print(x,y)

# x=mta_df['GTFS Latitude'] =39.12229
# y=mta_df['GTFS Longitude']=-77.1333

x=39.12229
y=-77.1333


result = search.by_coordinates(lat=x,lng=y, radius=5)[0]#.median_household_income

print(result)
# for zipcode in result:
#     print(zipcode.median_household_income,zipcode.zipcode)
# Out:
# Zipcode(zipcode_type='Standard', major_city='Derwood', post_office_city='Derwood, MD', common_city_list=['Derwood', 'Rockville'], county='Montgomery County', state='MD', lat=39.14, lng=-77.13, timezone='Eastern', radius_in_miles=4.0, area_code_list=['240', '301'], population=14295, population_density=1090.0, land_area_in_sqmi=13.11, water_area_in_sqmi=0.25, housing_units=5018, occupied_housing_units=4889, median_home_value=453900, median_household_income=120603, bounds_west=-77.177635, bounds_east=-77.099876, bounds_north=39.18584, bounds_south=39.101573, zipcode='20855', polygon=[[-77.130325, 39.112892], [-77.130615, 39.112911], [-77.130722, 39.112941], [-77.130775, 39.112987], [-77.130767, 39.113075], [-77.130783, 39.113101], [-77.130889, 39.113182], [-77.13108, 39.113254], [-77.131156, 39.113357], [-77.131263, 39.113414], [-77.131371, 39.113429], [-77.13153, 39.113452], [-77.131706, 39.11351], [-77.131782, 39.113586], [-77.131889, 39.113624], [-77.132347, 39.113533], [-77.132423, 39.113529], [-77.132591, 39.113468], [-77.132629, 39.113437], [-77.132659, 39.113384], [-77.132797, 39.113315], [-77.132888, 39.113227], [-77.13301, 39.113182], [-77.133071, 39.11314], [-77.133186, 39.113128], [-77.133255, 39.113098], [-77.133377, 39.113101], [-77.133522, 39.113056], [-77.133804, 39.113063], [-77.133872, 39.113098], [-77.133987, 39.113204], [-77.134033, 39.113224], [-77.134223, 39.113224], [-77.134368, 39.113182], [-77.13446, 39.113132], [-77.134696, 39.113124], [-77.134811, 39.113132], [-77.134933, 39.113166], [-77.135299, 39.11317], [-77.13552, 39.113277], [-77.135696, 39.113265], [-77.135749, 39.113